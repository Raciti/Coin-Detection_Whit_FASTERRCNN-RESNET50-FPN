# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import torch
from torchvision.io import read_image
ASSETS_DIRECTORY = "assets"

imgs_path = os.path.join(ASSETS_DIRECTORY, "/content/drive/MyDrive/Colab_Notebooks/Machine_Learning/Progetto/Dataset/Test/")
imgs = os.listdir(imgs_path)


print(len(imgs))
# Out:
# 13

# %%
img_path = imgs_path + imgs[0]
img_path
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/Machine_Learning/Progetto/Dataset/Test/10cent_601.jpg'

# %%
img = read_image(img_path)
img.shape
# Out:
# torch.Size([3, 150, 150])

# %% [markdown]
# data l'immagine i parametri sono
# - canali
# - altezza
# - larghezza

# %% [markdown]
# #Scrittura CSV

# %%
import csv

# %%
Data = []
labels = torch.tensor([1])
for i in range(len(imgs)):
  #print(i+1, "/", len(Masks))
  data = []
  


  """print(imgs[i])
  print(labels)
  print(box)"""
  data = [[imgs[i]]]

  Data.append(data)
    
print(len(Data))
print(Data[0])
# Out:
# 13
# [['10cent_601.jpg']]

# %%
csv_file = "/content/drive/MyDrive/Colab_Notebooks/Machine_Learning/Progetto/Dataset/testset.csv"
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    for riga in Data:
      writer.writerows(riga)

print(f"Dati salvati nel file CSV '{csv_file}' con successo.")
# Out:
# Dati salvati nel file CSV '/content/drive/MyDrive/Colab_Notebooks/Machine_Learning/Progetto/Dataset/testset.csv' con successo.

# %% [markdown]
# #Lettura CSV

# %%
import ast
import torch
# Percorso del file CSV da aprire
csv_file = "/content/drive/MyDrive/Colab_Notebooks/Machine_Learning/Progetto/Dataset/testset.csv"
# Lettura dei dati dal file CSV
with open(csv_file, mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
      #print(list(row))
      stringa = row[0]
      
      print("Nome Moneta:", stringa)
# Out:
# Nome Moneta: 10cent_601.jpg
# Nome Moneta: 10cent_602.jpg
# Nome Moneta: 10cent_603.jpg
# Nome Moneta: 10cent_604.jpg
# Nome Moneta: 10cent_605.jpg
# Nome Moneta: 10cent_606.jpg
# Nome Moneta: 10cent_607.jpg
# Nome Moneta: 10cent_608.jpg
# Nome Moneta: 10cent_609.jpg
# Nome Moneta: 10cent_610.jpg
# Nome Moneta: 10cent_611.jpg
# Nome Moneta: 10cent_612.jpg
# Nome Moneta: 10cent_613.jpg
